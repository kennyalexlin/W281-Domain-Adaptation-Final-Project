# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os

from utils import load_split_images

# %%
train, val, test = load_split_images('../OfficeCaltechDomainAdaptation/images/')

# %%
len(train[0]), len(val[0]), len(test[0])
# Out:
# (2081, 226, 226)

# %%
plt.imshow(train[3][0])
plt.title(f"{train[0][0]} - {train[1][0]}")
# Out:
# Text(0.5, 1.0, 'caltech10 - mouse')

# %%
plt.imshow(train[3][3])
plt.title(f"{train[0][3]} - {train[1][3]}")
# Out:
# Text(0.5, 1.0, 'caltech10 - projector')

# %%
plt.imshow(val[3][5])
plt.title(f"{val[0][5]} - {val[1][5]}")
# Out:
# Text(0.5, 1.0, 'dslr - bike')

# %%
plt.imshow(test[3][5])
plt.title(f"{test[0][5]} - {test[1][5]}")
# Out:
# Text(0.5, 1.0, 'webcam - bike')
